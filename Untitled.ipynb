# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("prouni_2005_2019.csv")

# %%
dados
# Out:
#          ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 0                       2005                    423
# 1                       2005                    423
# 2                       2005                    423
# 3                       2005                    423
# 4                       2005                    423
# ...                      ...                    ...
# 2692535                 2019                  18978
# 2692536                 2019                  18978
# 2692537                 2019                  18978
# 2692538                 2019                  18978
# 2692539                 2019                  18978
#
#                                             NOME_IES_BOLSA         TIPO_BOLSA  \
# 0        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 1        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 2        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# ...

# %%
dados.columns
# Out:
# Index(['ANO_CONCESSAO_BOLSA', 'CODIGO_EMEC_IES_BOLSA', 'NOME_IES_BOLSA',
#        'TIPO_BOLSA', 'MODALIDADE_ENSINO_BOLSA', 'NOME_CURSO_BOLSA',
#        'NOME_TURNO_CURSO_BOLSA', 'CPF_BENEFICIARIO_BOLSA',
#        'SEXO_BENEFICIARIO_BOLSA', 'RACA_BENEFICIARIO_BOLSA',
#        'DT_NASCIMENTO_BENEFICIARIO', 'BENEFICIARIO_DEFICIENTE_FISICO',
#        'REGIAO_BENEFICIARIO_BOLSA', 'SIGLA_UF_BENEFICIARIO_BOLSA',
#        'MUNICIPIO_BENEFICIARIO_BOLSA', 'idade'],
#       dtype='object')

# %%
n_dados = dados[['ANO_CONCESSAO_BOLSA', 'NOME_IES_BOLSA',
       'TIPO_BOLSA', 'MODALIDADE_ENSINO_BOLSA', 'NOME_CURSO_BOLSA',
       'NOME_TURNO_CURSO_BOLSA',
       'SEXO_BENEFICIARIO_BOLSA', 'RACA_BENEFICIARIO_BOLSA',
        'BENEFICIARIO_DEFICIENTE_FISICO',
       'REGIAO_BENEFICIARIO_BOLSA', 'SIGLA_UF_BENEFICIARIO_BOLSA', 'idade']].copy()

# %%
n_dados.columns = ['ANO', 'NOME_IES',
       'TIPO_BOLSA', 'MODALIDADE', 'NOME_CURSO', 'TURNO',
       'SEXO_BENEFICIARIO', 'RACA_BENEFICIARIO',
        'BENEFICIARIO_DEFICIENTE_FISICO',
       'REGIAO_BENEFICIARIO', 'SIGLA_UF_BENEFICIARIO', 'idade']

# %%
n_dados.shape
# Out:
# (2692540, 12)

# %%
n_dados
# Out:
#           ANO                                           NOME_IES  \
# 0        2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 1        2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 2        2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 3        2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 4        2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# ...       ...                                                ...
# 2692535  2019               FACULDADE REBOUAAS DE CAMPINA GRANDE
# 2692536  2019               FACULDADE REBOUAAS DE CAMPINA GRANDE
# 2692537  2019               FACULDADE REBOUAAS DE CAMPINA GRANDE
# 2692538  2019               FACULDADE REBOUAAS DE CAMPINA GRANDE
# 2692539  2019               FACULDADE REBOUAAS DE CAMPINA GRANDE
#
#                 TIPO_BOLSA  MODALIDADE                  NOME_CURSO     TURNO  \
# 0        BOLSA PARCIAL 50%  PRESENCIAL                  Enfermagem  Integral
# ...

# %%
n_dados.nunique()
# Out:
# ANO                                 15
# NOME_IES                          2767
# TIPO_BOLSA                           3
# MODALIDADE                           2
# NOME_CURSO                        3644
# TURNO                                5
# SEXO_BENEFICIARIO                    2
# RACA_BENEFICIARIO                    6
# BENEFICIARIO_DEFICIENTE_FISICO       2
# REGIAO_BENEFICIARIO                  5
# SIGLA_UF_BENEFICIARIO               27
# idade                              107
# dtype: int64

# %%
n_dados.dtypes
# Out:
# ANO                                 int64
# NOME_IES                           object
# TIPO_BOLSA                         object
# MODALIDADE                         object
# NOME_CURSO                         object
# TURNO                              object
# SEXO_BENEFICIARIO                  object
# RACA_BENEFICIARIO                  object
# BENEFICIARIO_DEFICIENTE_FISICO     object
# REGIAO_BENEFICIARIO                object
# SIGLA_UF_BENEFICIARIO              object
# idade                             float64
# dtype: object

# %%
n_dados["TIPO_BOLSA"].unique()
# Out:
# array(['BOLSA PARCIAL 50%', 'BOLSA INTEGRAL', 'BOLSA COMPLEMENTAR 25%'],
#       dtype=object)

# %%
n_dados["TURNO"].unique()
# Out:
# array(['Integral', 'Noturno', 'Matutino', 'Vespertino', 'A Distancia'],
#       dtype=object)

# %%
n_dados["BENEFICIARIO_DEFICIENTE_FISICO"].unique()
# Out:
# array(['nao', 'sim'], dtype=object)

# %%
n_dados["idade"] = n_dados["idade"].astype(int)

# %%
n_dados['REGIAO_BENEFICIARIO'].value_counts()
# Out:
# SUDESTE         1289321
# SUL              491560
# NORDESTE         486819
# CENTRO-OESTE     247089
# NORTE            177349
# Name: REGIAO_BENEFICIARIO, dtype: int64

# %%
cols = ['REGIAO_BENEFICIARIO', 'TIPO_BOLSA', 'MODALIDADE', 'SEXO_BENEFICIARIO',
        'RACA_BENEFICIARIO', 'BENEFICIARIO_DEFICIENTE_FISICO']


for i in range(len(cols)):
    caso = n_dados[cols[i]].value_counts()
    caso.plot.pie(autopct='%1.1f%%', startangle=90)
    plt.axis('equal')  # Hace que el diagrama de torta sea circular
    plt.title(f'Distribucao das bolsas por {cols[i]}')
    plt.ylabel('')  # Eliminar la etiqueta del eje y
    plt.show()
    
# fig.text(0.13, 0.95, 'Prouni - Overall',
         #fontsize=18, fontweight='bold', fontfamily='garamond') 
# plt.show()

# %% [markdown]
# ### Idades

# %%
anos= [0,20,25,30,35,40,45,50,55,60,70,150]
grupos_anos = ['0-19','20-24','25-29','30-34', '35-39','40-44',
          '45-49','50-54', '55-59', '60-69', '70+']

n_dados['GRUPO_IDADE'] = pd.cut(n_dados['idade'], bins=anos, labels=grupos_anos, right=False)
