# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7076\265554930.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
dados = pd.read_csv("prouni_2005_2019.csv")

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2692540 entries, 0 to 2692539
# Data columns (total 16 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   ANO_CONCESSAO_BOLSA             int64
#  1   CODIGO_EMEC_IES_BOLSA           int64
#  2   NOME_IES_BOLSA                  object
#  3   TIPO_BOLSA                      object
#  4   MODALIDADE_ENSINO_BOLSA         object
#  5   NOME_CURSO_BOLSA                object
#  6   NOME_TURNO_CURSO_BOLSA          object
#  7   CPF_BENEFICIARIO_BOLSA          object
#  8   SEXO_BENEFICIARIO_BOLSA         object
#  9   RACA_BENEFICIARIO_BOLSA         object
#  10  DT_NASCIMENTO_BENEFICIARIO      object
#  11  BENEFICIARIO_DEFICIENTE_FISICO  object
#  12  REGIAO_BENEFICIARIO_BOLSA       object
#  13  SIGLA_UF_BENEFICIARIO_BOLSA     object
#  14  MUNICIPIO_BENEFICIARIO_BOLSA    object
#  15  idade                           float64
# dtypes: float64(1), int64(2), object(13)
# memory usage: 328.7+ MB

# %%
dados
# Out:
#          ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 0                       2005                    423
# 1                       2005                    423
# 2                       2005                    423
# 3                       2005                    423
# 4                       2005                    423
# ...                      ...                    ...
# 2692535                 2019                  18978
# 2692536                 2019                  18978
# 2692537                 2019                  18978
# 2692538                 2019                  18978
# 2692539                 2019                  18978
#
#                                             NOME_IES_BOLSA         TIPO_BOLSA  \
# 0        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 1        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 2        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 3        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 4        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# ...                                                    ...                ...
# 2692535               FACULDADE REBOUAAS DE CAMPINA GRANDE     BOLSA INTEGRAL
# 2692536               FACULDADE REBOUAAS DE CAMPINA GRANDE     BOLSA INTEGRAL
# 2692537               FACULDADE REBOUAAS DE CAMPINA GRANDE     BOLSA INTEGRAL
# 2692538               FACULDADE REBOUAAS DE CAMPINA GRANDE     BOLSA INTEGRAL
# 2692539               FACULDADE REBOUAAS DE CAMPINA GRANDE     BOLSA INTEGRAL
#
#         MODALIDADE_ENSINO_BOLSA            NOME_CURSO_BOLSA  \
# 0                    PRESENCIAL                  Enfermagem
# 1                    PRESENCIAL              Servico Social
# 2                    PRESENCIAL              Servico Social
# 3                    PRESENCIAL       Ciencia Da Computacao
# 4                    PRESENCIAL       Ciencia Da Computacao
# ...                         ...                         ...
# 2692535              PRESENCIAL                    FarmAcia
# 2692536              PRESENCIAL  GestAo De Recursos Humanos
# 2692537              PRESENCIAL  GestAo De Recursos Humanos
# 2692538              PRESENCIAL  GestAo De Recursos Humanos
# 2692539              PRESENCIAL        Medicina VeterinAria
#
#         NOME_TURNO_CURSO_BOLSA CPF_BENEFICIARIO_BOLSA SEXO_BENEFICIARIO_BOLSA  \
# 0                     Integral            ***264740**                       F
# 1                      Noturno            ***976940**                       F
# 2                      Noturno            ***045340**                       F
# 3                      Noturno            ***988420**                       M
# 4                      Noturno            ***378080**                       M
# ...                        ...                    ...                     ...
# 2692535                Noturno          ***70755437**                       F
# 2692536               Matutino          ***23845493**                       F
# 2692537               Matutino          ***62578423**                       M
# 2692538                Noturno          ***21568498**                       F
# 2692539               Matutino          ***34469421**                       M
#
#         RACA_BENEFICIARIO_BOLSA DT_NASCIMENTO_BENEFICIARIO  \
# 0                        Branca                 1987-02-17
# 1                         Parda                 1986-06-14
# 2                         Parda                 1984-06-03
# 3                        Branca                 1987-10-19
# 4                       Amarela                 1987-07-20
# ...                         ...                        ...
# 2692535                   Parda                 2001-04-05
# 2692536                   Parda                 2001-06-16
# 2692537                  Branca                 1992-12-13
# 2692538                   Parda                 1996-12-27
# 2692539                  Branca                 1985-03-14
#
#         BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO_BOLSA  \
# 0                                  nao                       SUL
# 1                                  nao                       SUL
# 2                                  nao                       SUL
# 3                                  nao                       SUL
# 4                                  nao                       SUL
# ...                                ...                       ...
# 2692535                            nao                  NORDESTE
# 2692536                            nao                  NORDESTE
# 2692537                            nao                  NORDESTE
# 2692538                            nao                  NORDESTE
# 2692539                            nao                  NORDESTE
#
#         SIGLA_UF_BENEFICIARIO_BOLSA MUNICIPIO_BENEFICIARIO_BOLSA  idade
# 0                                RS                 santo angelo   34.0
# 1                                RS         frederico westphalen   35.0
# 2                                RS         frederico westphalen   37.0
# 3                                RS         frederico westphalen   33.0
# 4                                RS         frederico westphalen   34.0
# ...                             ...                          ...    ...
# 2692535                          PE              santa terezinha   20.0
# 2692536                          PB                     aroeiras   20.0
# 2692537                          PB               campina grande   28.0
# 2692538                          PB                   lagoa seca   24.0
# 2692539                          PB               campina grande   36.0
#
# [2692540 rows x 16 columns]

# %%
dados.columns
# Out:
# Index(['ANO_CONCESSAO_BOLSA', 'CODIGO_EMEC_IES_BOLSA', 'NOME_IES_BOLSA',
#        'TIPO_BOLSA', 'MODALIDADE_ENSINO_BOLSA', 'NOME_CURSO_BOLSA',
#        'NOME_TURNO_CURSO_BOLSA', 'CPF_BENEFICIARIO_BOLSA',
#        'SEXO_BENEFICIARIO_BOLSA', 'RACA_BENEFICIARIO_BOLSA',
#        'DT_NASCIMENTO_BENEFICIARIO', 'BENEFICIARIO_DEFICIENTE_FISICO',
#        'REGIAO_BENEFICIARIO_BOLSA', 'SIGLA_UF_BENEFICIARIO_BOLSA',
#        'MUNICIPIO_BENEFICIARIO_BOLSA', 'idade'],
#       dtype='object')

# %%
df = dados[['ANO_CONCESSAO_BOLSA', 'NOME_IES_BOLSA',
       'TIPO_BOLSA', 'MODALIDADE_ENSINO_BOLSA', 'NOME_CURSO_BOLSA',
       'NOME_TURNO_CURSO_BOLSA',
       'SEXO_BENEFICIARIO_BOLSA', 'RACA_BENEFICIARIO_BOLSA',
        'BENEFICIARIO_DEFICIENTE_FISICO',
       'REGIAO_BENEFICIARIO_BOLSA', 'SIGLA_UF_BENEFICIARIO_BOLSA', 'idade']].copy()

# %%
df.shape
# Out:
# (2692540, 12)

# %%
df
# Out:
#          ANO_CONCESSAO_BOLSA  \
# 0                       2005
# 1                       2005
# 2                       2005
# 3                       2005
# 4                       2005
# ...                      ...
# 2692535                 2019
# 2692536                 2019
# 2692537                 2019
# 2692538                 2019
# 2692539                 2019
#
#                                             NOME_IES_BOLSA         TIPO_BOLSA  \
# 0        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 1        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 2        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 3        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 4        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# ...                                                    ...                ...
# 2692535               FACULDADE REBOUAAS DE CAMPINA GRANDE     BOLSA INTEGRAL
# 2692536               FACULDADE REBOUAAS DE CAMPINA GRANDE     BOLSA INTEGRAL
# 2692537               FACULDADE REBOUAAS DE CAMPINA GRANDE     BOLSA INTEGRAL
# 2692538               FACULDADE REBOUAAS DE CAMPINA GRANDE     BOLSA INTEGRAL
# 2692539               FACULDADE REBOUAAS DE CAMPINA GRANDE     BOLSA INTEGRAL
#
#         MODALIDADE_ENSINO_BOLSA            NOME_CURSO_BOLSA  \
# 0                    PRESENCIAL                  Enfermagem
# 1                    PRESENCIAL              Servico Social
# 2                    PRESENCIAL              Servico Social
# 3                    PRESENCIAL       Ciencia Da Computacao
# 4                    PRESENCIAL       Ciencia Da Computacao
# ...                         ...                         ...
# 2692535              PRESENCIAL                    FarmAcia
# 2692536              PRESENCIAL  GestAo De Recursos Humanos
# 2692537              PRESENCIAL  GestAo De Recursos Humanos
# 2692538              PRESENCIAL  GestAo De Recursos Humanos
# 2692539              PRESENCIAL        Medicina VeterinAria
#
#         NOME_TURNO_CURSO_BOLSA SEXO_BENEFICIARIO_BOLSA  \
# 0                     Integral                       F
# 1                      Noturno                       F
# 2                      Noturno                       F
# 3                      Noturno                       M
# 4                      Noturno                       M
# ...                        ...                     ...
# 2692535                Noturno                       F
# 2692536               Matutino                       F
# 2692537               Matutino                       M
# 2692538                Noturno                       F
# 2692539               Matutino                       M
#
#         RACA_BENEFICIARIO_BOLSA BENEFICIARIO_DEFICIENTE_FISICO  \
# 0                        Branca                            nao
# 1                         Parda                            nao
# 2                         Parda                            nao
# 3                        Branca                            nao
# 4                       Amarela                            nao
# ...                         ...                            ...
# 2692535                   Parda                            nao
# 2692536                   Parda                            nao
# 2692537                  Branca                            nao
# 2692538                   Parda                            nao
# 2692539                  Branca                            nao
#
#         REGIAO_BENEFICIARIO_BOLSA SIGLA_UF_BENEFICIARIO_BOLSA  idade
# 0                             SUL                          RS   34.0
# 1                             SUL                          RS   35.0
# 2                             SUL                          RS   37.0
# 3                             SUL                          RS   33.0
# 4                             SUL                          RS   34.0
# ...                           ...                         ...    ...
# 2692535                  NORDESTE                          PE   20.0
# 2692536                  NORDESTE                          PB   20.0
# 2692537                  NORDESTE                          PB   28.0
# 2692538                  NORDESTE                          PB   24.0
# 2692539                  NORDESTE                          PB   36.0
#
# [2692540 rows x 12 columns]

# %%
df.nunique()
# Out:
# ANO_CONCESSAO_BOLSA                 15
# NOME_IES_BOLSA                    2767
# TIPO_BOLSA                           3
# MODALIDADE_ENSINO_BOLSA              2
# NOME_CURSO_BOLSA                  3644
# NOME_TURNO_CURSO_BOLSA               5
# SEXO_BENEFICIARIO_BOLSA              2
# RACA_BENEFICIARIO_BOLSA              6
# BENEFICIARIO_DEFICIENTE_FISICO       2
# REGIAO_BENEFICIARIO_BOLSA            5
# SIGLA_UF_BENEFICIARIO_BOLSA         27
# idade                              107
# dtype: int64

# %%
df.dtypes
# Out:
# ANO_CONCESSAO_BOLSA                 int64
# NOME_IES_BOLSA                     object
# TIPO_BOLSA                         object
# MODALIDADE_ENSINO_BOLSA            object
# NOME_CURSO_BOLSA                   object
# NOME_TURNO_CURSO_BOLSA             object
# SEXO_BENEFICIARIO_BOLSA            object
# RACA_BENEFICIARIO_BOLSA            object
# BENEFICIARIO_DEFICIENTE_FISICO     object
# REGIAO_BENEFICIARIO_BOLSA          object
# SIGLA_UF_BENEFICIARIO_BOLSA        object
# idade                             float64
# dtype: object

# %%
df["TIPO_BOLSA"].unique()
# Out:
# array(['BOLSA PARCIAL 50%', 'BOLSA INTEGRAL', 'BOLSA COMPLEMENTAR 25%'],
#       dtype=object)

# %%
df["NOME_TURNO_CURSO_BOLSA"].unique()
# Out:
# array(['Integral', 'Noturno', 'Matutino', 'Vespertino', 'A Distancia'],
#       dtype=object)

# %%
df["BENEFICIARIO_DEFICIENTE_FISICO"].unique()
# Out:
# array(['nao', 'sim'], dtype=object)

# %%
df["idade"] = df["idade"].astype(int)

# %%
df['REGIAO_BENEFICIARIO_BOLSA'].value_counts()
# Out:
# REGIAO_BENEFICIARIO_BOLSA
# SUDESTE         1289321
# SUL              491560
# NORDESTE         486819
# CENTRO-OESTE     247089
# NORTE            177349
# Name: count, dtype: int64

# %%
cols = ['REGIAO_BENEFICIARIO_BOLSA', 'TIPO_BOLSA', 'MODALIDADE_ENSINO_BOLSA', 'SEXO_BENEFICIARIO_BOLSA']

cols_ = ['região do beneficiario', 'tipo de bolsa', 'modalidade', 'sexo do beneficiario']
fig, axs = plt.subplots(2, 2, figsize=(15, 18))

# Iterar sobre las columnas y sus índices
for i in range(len(cols)):
    try:
        # Calcular las coordenadas del subplot
        row = i // 2
        col = i % 2

        # Obtener la distribución de valores para la columna actual
        caso = df[cols[i]].value_counts()

        # Crear el gráfico de torta en el subplot correspondiente
        caso.plot.pie(autopct='%1.1f%%', startangle=90, ax=axs[row, col])
        axs[row, col].set_title(f'Distribucao das bolsas por {cols_[i]}')
        axs[row, col].set_ylabel('')
        plt.gca().set_aspect('equal')

    except:
        continue


# Ajustar espaciado entre subplots
plt.tight_layout()

# Mostrar los subplots
plt.show()

# %%
total = len(df)
porcentajes = df['RACA_BENEFICIARIO_BOLSA'].value_counts() / total * 100

# Crear el gráfico de barras
plt.figure(figsize=(9, 6))
sns.barplot(x=porcentajes.index, y=porcentajes.values, palette='viridis')

# Establecer etiquetas y título
plt.xlabel('Raça')
plt.title('Porcentagem dos Beneficiarios por Raça')

for index, value in enumerate(porcentajes):
    plt.text(index, value + 0.5, f'{value:.2f}%', ha='center', va='bottom', fontsize=10)

plt.tick_params(axis= 'both', bottom=True, labelbottom=True, left = False, labelleft= False)
# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7076\1864810817.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=porcentajes.index, y=porcentajes.values, palette='viridis')

# %% [markdown]
# ### Idades

# %%
df["Ano_nascimento"] = dados["DT_NASCIMENTO_BENEFICIARIO"].str.extract('(\\d+)').astype(int)

# %%
df["R_Anos"] = df['ANO_CONCESSAO_BOLSA'] - df['Ano_nascimento']

# %%
df['Dif_idade'] = df['idade']- df["R_Anos"]

# %%
df['Dif_idade'].value_counts()
# Out:
# Dif_idade
# 6     246631
# 5     241905
# 3     240101
# 4     237406
# 2     229266
# 7     212645
# 8     177495
# 9     174812
# 10    166815
# 11    154950
# 12    152671
# 13    119911
# 14    106389
# 15    106066
# 16     72804
# 1      52673
# Name: count, dtype: int64

# %%
df[df['idade']==2].head()
# Out:
#         ANO_CONCESSAO_BOLSA  \
# 124782                 2006
# 156504                 2006
# 202492                 2006
# 453478                 2009
# 467306                 2009
#
#                                            NOME_IES_BOLSA         TIPO_BOLSA  \
# 124782  INSTITUTO DE EDUCACAO SUPERIOR UNYAHNA DE BARR...  BOLSA PARCIAL 50%
# 156504      CENTRO UNIVERSITARIO DO LESTE DE MINAS GERAIS     BOLSA INTEGRAL
# 202492  Estacio FIB - Centro Universitario Estacio da ...     BOLSA INTEGRAL
# 453478              UNIVERSIDADE DO SUL DE SANTA CATARINA     BOLSA INTEGRAL
# 467306  FACULDADE DE ESTUDOS ADMINISTRATIVOS DE MINAS ...     BOLSA INTEGRAL
#
#        MODALIDADE_ENSINO_BOLSA             NOME_CURSO_BOLSA  \
# 124782              PRESENCIAL                Administracao
# 156504              PRESENCIAL                   Enfermagem
# 202492              PRESENCIAL                Administracao
# 453478                     EAD  Gestao De Seguranca Publica
# 467306                     EAD           Ciencias Contabeis
#
#        NOME_TURNO_CURSO_BOLSA SEXO_BENEFICIARIO_BOLSA RACA_BENEFICIARIO_BOLSA  \
# 124782                Noturno                       F                  Branca
# 156504               Matutino                       F                   Parda
# 202492               Matutino                       F                   Parda
# 453478            A Distancia                       M                   Parda
# 467306            A Distancia                       M                   Parda
#
#        BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO_BOLSA  \
# 124782                            nao                  NORDESTE
# 156504                            nao                   SUDESTE
# 202492                            nao                  NORDESTE
# 453478                            nao                   SUDESTE
# 467306                            nao                   SUDESTE
#
#        SIGLA_UF_BENEFICIARIO_BOLSA  idade  Ano_nascimento  R_Anos  Dif_idade
# 124782                          BA      2            2019     -13         15
# 156504                          MG      2            2019     -13         15
# 202492                          BA      2            2019     -13         15
# 453478                          MG      2            2019     -10         12
# 467306                          MG      2            2019     -10         12

# %%
df['idade'].describe()
# Out:
# count    2.692540e+06
# mean     3.137911e+01
# std      7.974098e+00
# min      2.000000e+00
# 25%      2.500000e+01
# 50%      3.000000e+01
# 75%      3.500000e+01
# max      1.500000e+02
# Name: idade, dtype: float64

# %%
anos= [0,20,25,30,35,40,45,50,55,60, 65, 70,151]
grupos_anos = ['0-19','20-24','25-29','30-34', '35-39','40-44',
          '45-49','50-54', '55-59', '60-64', '65-69', '70+']

df['GRUPO_IDADE'] = pd.cut(df['idade'], bins=anos, labels=grupos_anos, right=False)

# %%
df.head(2)
# Out:
#    ANO_CONCESSAO_BOLSA                                     NOME_IES_BOLSA  \
# 0                 2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# 1                 2005  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
#
#           TIPO_BOLSA MODALIDADE_ENSINO_BOLSA NOME_CURSO_BOLSA  \
# 0  BOLSA PARCIAL 50%              PRESENCIAL       Enfermagem
# 1  BOLSA PARCIAL 50%              PRESENCIAL   Servico Social
#
#   NOME_TURNO_CURSO_BOLSA SEXO_BENEFICIARIO_BOLSA RACA_BENEFICIARIO_BOLSA  \
# 0               Integral                       F                  Branca
# 1                Noturno                       F                   Parda
#
#   BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO_BOLSA  \
# 0                            nao                       SUL
# 1                            nao                       SUL
#
#   SIGLA_UF_BENEFICIARIO_BOLSA  idade  Ano_nascimento  R_Anos  Dif_idade  \
# 0                          RS     34            1987      18         16
# 1                          RS     35            1986      19         16
#
#   GRUPO_IDADE
# 0       30-34
# 1       35-39

# %% [markdown]
# ### Programas predileitos por região

# %%
regioes = df['REGIAO_BENEFICIARIO_BOLSA'].unique()

regioes = regioes.astype(object)

# Eliminar valores nulos
regioes = regioes[~pd.isnull(regioes)]

# %%
# Calcular el número de filas necesarias
num_filas = (len(regioes) + 1) // 2

# Crear una figura y ejes con subplots
fig, axs = plt.subplots(num_filas, 2, figsize=(15, 6 * num_filas))

# Iterar sobre las regiones y sus índices
for i, regiao in enumerate(regioes):
    try:
        # Calcular las coordenadas del subplot
        row = i // 2
        col = i % 2

        # Filtrar los datos por región
        dados_regiao = df[df['REGIAO_BENEFICIARIO_BOLSA'] == regiao]
        top_10_cursos = dados_regiao['NOME_CURSO_BOLSA'].value_counts().head(10)

        # Crear el gráfico de barras en el subplot correspondiente
        axs[row, col].bar(top_10_cursos.index, top_10_cursos.values)
        axs[row, col].set_title(f'Top 10 Cursos no {regiao}')
        axs[row, col].set_xlabel('Curso')
        axs[row, col].set_ylabel('Número de Bolsas')
        axs[row, col].tick_params(axis='x', rotation=75)

    except:
        continue

# Filtrar los datos do país
top_10_cursos = df['NOME_CURSO_BOLSA'].value_counts().head(10)

        # Crear el gráfico de barras en el subplot correspondiente
axs[2, 1].bar(top_10_cursos.index, top_10_cursos.values)
axs[2, 1].set_title(f'Top 10 Cursos no Pais')
axs[2, 1].set_xlabel('Curso')
axs[2, 1].set_ylabel('Número de Bolsas')
axs[2, 1].tick_params(axis='x', rotation=75)

# Ajustar espaciado entre subplots
plt.tight_layout()

# Mostrar los subplots
plt.show()

# %%
# Calcular el número de filas necesarias
num_filas = (len(regioes) + 1) // 2

# Crear una figura y ejes con subplots
fig, axs = plt.subplots(num_filas, 2, figsize=(15, 6 * num_filas))

# Iterar sobre las regiones y sus índices
for i, regiao in enumerate(regioes):
    try:
        # Calcular las coordenadas del subplot
        row = i // 2
        col = i % 2

        # Filtrar los datos por región
        dados_regiao = df[df['REGIAO_BENEFICIARIO_BOLSA'] == regiao]
        sexo_regiao = dados_regiao['SEXO_BENEFICIARIO_BOLSA'].value_counts()

        # Crear el gráfico de barras en el subplot correspondiente
        axs[row, col].bar(sexo_regiao.index, sexo_regiao.values)
        axs[row, col].set_title(f'Distribuição do sexo no {regiao}')
        axs[row, col].set_xlabel('Sexo do Beneficiario')
        axs[row, col].set_ylabel('Número de Bolsas')
        axs[row, col].tick_params(axis='x')

    except:
        continue

# Filtrar los datos do país
sexo_pais = df['SEXO_BENEFICIARIO_BOLSA'].value_counts()

        # Crear el gráfico de barras en el subplot correspondiente
axs[2, 1].bar(sexo_pais.index, sexo_pais.values)
axs[2, 1].set_title(f'Distribuição do sexo no  Pais')
axs[2, 1].set_xlabel('Sexo do Beneficiario')
axs[2, 1].set_ylabel('Número de Bolsas')
axs[2, 1].tick_params(axis='x')

# Ajustar espaciado entre subplots
plt.tight_layout()

# Mostrar los subplots
plt.show()

# %% [markdown]
# ### Programas predileitos por sexo M vs F

# %%
plt.figure(figsize = (12, 6))


# Filtrar dados

grupo_masc = df[df['SEXO_BENEFICIARIO_BOLSA']=='M']
top_10_cursos_m = grupo_masc['NOME_CURSO_BOLSA'].value_counts().head(10)

grupo_fem = df[df['SEXO_BENEFICIARIO_BOLSA']=='F']
top_10_cursos_f = grupo_fem['NOME_CURSO_BOLSA'].value_counts().head(10)

# Ajustar espaciado entre subplots


plt.subplot(121)
sns.barplot(x=top_10_cursos_m.index, y=top_10_cursos_m.values, palette='muted')
plt.title(f'Top 10 Cursos no Pais entre Masculinos')
plt.xlabel('Curso')
plt.ylabel('Número de Bolsas')
plt.tick_params(axis='x', rotation=75)


plt.subplot(122)
sns.barplot(x=top_10_cursos_f.index, y=top_10_cursos_f.values, palette='muted')
plt.title(f'Top 10 Cursos no Pais entre Femeninas')
plt.xlabel('Curso')
plt.ylabel('Número de Bolsas')
plt.tick_params(axis='x', rotation=75)

plt.tight_layout()


plt.show()
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7076\2560396381.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_cursos_m.index, y=top_10_cursos_m.values, palette='muted')
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7076\2560396381.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_cursos_f.index, y=top_10_cursos_f.values, palette='muted')

# %% [markdown]
# ### Programas predileitos por Faixa Etária

# %%
# Calcular el número de filas necesarias
grupos_anos = ['0-19','20-24','25-29','30-34', '35-39','40-44',
          '45-49','50-54', '55-59', '60-64', '65-69', '70+']
num_filas = (len(grupos_anos) + 1) // 2

# Crear una figura y ejes con subplots
fig, axs = plt.subplots(num_filas, 2, figsize=(15, 6 * num_filas))

# Iterar sobre las regiones y sus índices
for i, grupo in enumerate(grupos_anos):
    try:
        # Calcular las coordenadas del subplot
        row = i // 2
        col = i % 2

        # Filtrar los datos por región
        dados_grupo = df[df['GRUPO_IDADE'] == grupo]
        top_10_cursos = dados_grupo['NOME_CURSO_BOLSA'].value_counts().head(10)

        # Crear el gráfico de barras en el subplot correspondiente
        axs[row, col].bar(top_10_cursos.index, top_10_cursos.values)
        axs[row, col].set_title(f'Top 10 curso em {grupo} anos')
        axs[row, col].set_xlabel('Cursos predileitos')
        axs[row, col].set_ylabel('Número de Bolsas')
        axs[row, col].tick_params(axis='x', rotation=75)

    except:
        continue

# Ajustar espaciado entre subplots
plt.tight_layout()

# Mostrar los subplots
plt.show()

# %% [markdown]
# ### Distribuição das idades

# %%
sns.distplot(df['idade'])

plt.show()
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7076\1582278429.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['idade'])

# %%
len(df['GRUPO_IDADE'].unique())
# Out:
# 12

# %%
# Calcular el número de filas necesarias
num_filas = (len(regioes) + 1) // 2

# Crear una figura y ejes con subplots
fig, axs = plt.subplots(num_filas, 2, figsize=(15, 6 * num_filas))

# Iterar sobre las regiones y sus índices
for i, regiao in enumerate(regioes):
    try:
        # Calcular las coordenadas del subplot
        row = i // 2
        col = i % 2

        # Filtrar los datos por región
        dados_regiao = df[df['REGIAO_BENEFICIARIO_BOLSA'] == regiao]

        # Crear el gráfico de countplot en el subplot correspondiente
        sns.countplot(data=dados_regiao, x='GRUPO_IDADE', ax=axs[row, col])
        axs[row, col].set_title(f'Distribução de Idade no {regiao}')
        axs[row, col].set_xlabel('Rango de Idade')
        axs[row, col].set_ylabel('Número de Bolsas')
        axs[row, col].tick_params(axis='x', rotation=0)

    except:
        continue

# Filtrar los datos para todo el país
idade_pais = df['GRUPO_IDADE']

# Crear el gráfico de countplot para todo el país en el último subplot
sns.countplot(data=df, x='GRUPO_IDADE', ax=axs[num_filas-1, 1])
axs[num_filas-1, 1].set_title('Distribução de Idade no País')
axs[num_filas-1, 1].set_xlabel('Rango de Idade')
axs[num_filas-1, 1].set_ylabel('Número de Bolsas')
axs[num_filas-1, 1].tick_params(axis='x', rotation=0)

# Ajustar espaciado entre subplots
plt.tight_layout()

# Mostrar los subplots
plt.show()

# %% [markdown]
# ### Escolha de IES

# %%
num_filas = len(regioes) + 1

# Crear una figura y ejes con subplots
fig, axs = plt.subplots(num_filas, 1, figsize=(10, 6 * num_filas))

# Iterar sobre las regiones y sus índices
for i, regiao in enumerate(regioes):
    try:
        # Filtrar los datos por región
        dados_regiao = df[df['REGIAO_BENEFICIARIO_BOLSA'] == regiao]
        top_10_ies = dados_regiao['NOME_IES_BOLSA'].value_counts().head(10)
        
        # Crear el gráfico de countplot en el subplot correspondiente
        sns.barplot(x=top_10_ies.values, y=top_10_ies.index, ax=axs[i], palette='viridis')
        axs[i].set_title(f'Top 10 IES no {regiao}')
        axs[i].set_xlabel('Numero de Bolsas')
        axs[i].set_ylabel('IES')
        

    except:
        continue

# Gráfico para todo el país
top_10_ies_pais = df['NOME_IES_BOLSA'].value_counts().head(10)
sns.barplot(x=top_10_ies_pais.values, y=top_10_ies_pais.index, ax=axs[num_filas-1], palette='viridis')
axs[num_filas-1].set_title('Top 10 IES no Pais')
axs[num_filas-1].set_xlabel('Numero de Bolsas')
axs[num_filas-1].set_ylabel('IES')

# Ajustar espaciado entre subplots
plt.tight_layout()

# Mostrar los subplots
plt.show()
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7076\1008746412.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_ies.values, y=top_10_ies.index, ax=axs[i], palette='viridis')
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7076\1008746412.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_ies.values, y=top_10_ies.index, ax=axs[i], palette='viridis')
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7076\1008746412.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_ies.values, y=top_10_ies.index, ax=axs[i], palette='viridis')
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7076\1008746412.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_ies.values, y=top_10_ies.index, ax=axs[i], palette='viridis')
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7076\1008746412.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_ies.values, y=top_10_ies.index, ax=axs[i], palette='viridis')
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7076\1008746412.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_ies_pais.values, y=top_10_ies_pais.index, ax=axs[num_filas-1], palette='viridis')
